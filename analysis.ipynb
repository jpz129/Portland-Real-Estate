# %% [markdown]
# 1. Plan and form questions
# 2. Collect data
# 3. Explore data
# 4. Model data
# 5. Deploy

# %% [markdown]
# ## Questions
#
# - Can we see which areas tend to have private feeling lots?
# - How do these houses deemed as private compare price-wise?
# - Are private houses older than new constructions?
# - What's the balance between privacy and walkability?

# %% [markdown]
# ## Data Collection

# %%
# not really feeling this scraper, but it's working at least
# will probably find another option, hopefully more textual
! python scraper.py
# Out:
# **********
# $129,500
# https://ap.rdcpix.com/eecee80df6d457318a10899adcd1f334l-m2252899816od-w480_h360.jpg
# 3bed2bath1,680sqft13313 SE Schiller St, Portland, OR 97236
# 13313 SE Schiller St, Portland, OR 97236
# 3bed2bath1,680sqft
#
# **********
# $389,999
# https://ap.rdcpix.com/ce1c7c37d7841dea89e9f06190fff401l-m176078026od-w480_h360.jpg
# 3bed2bath1,497sqft6,970sqft lot7954 SE Raymond Ct, Portland, OR 97206
# 7954 SE Raymond Ct, Portland, OR 97206
# 3bed2bath1,497sqft6,970sqft lot
#
# **********
# $325,000
# https://ap.rdcpix.com/1d29986ad36c8f2f0adefd6b05cb7622l-m3703359192od-w480_h360.jpg
# 2bed1bath960sqft4,792sqft lot5603 SE Flavel St, Portland, OR 97206
# 5603 SE Flavel St, Portland, OR 97206
# 2bed1bath960sqft4,792sqft lot
#
# **********
#
# **********
# $275,000
# https://ap.rdcpix.com/057ac3249bf15c23ff0b8b7543807e61l-m819100710od-w480_h360.jpg
# 1bed1bath564sqft5,227sqft lot4835 NE 92nd Ave, Portland, OR 97220
# 4835 NE 92nd Ave, Portland, OR 97220
# ...

# %% [markdown]
# ### Data Needs
#
# - Text describing property
# - Location of property (geo-locs would be ideal)
# - Price
